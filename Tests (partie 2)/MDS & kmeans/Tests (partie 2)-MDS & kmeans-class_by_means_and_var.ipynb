# %%
import pandas as pd
import numpy as np
from sklearn.manifold import MDS
from sklearn.cluster import AgglomerativeClustering
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster.hierarchy import dendrogram
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import adjusted_rand_score

# %%
spotify_songs = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')


Q1 = np.percentile(spotify_songs.duration_ms, 25,
                   interpolation = 'midpoint')
Q3 = np.percentile(spotify_songs.duration_ms, 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

"""
mask = (spotify_songs.duration_ms < (Q3+1.5*IQR))
mask2 = spotify_songs.duration_ms > (Q1-1.5*IQR)
spotify_data_cleaned = spotify_songs.loc[mask]
spotify_data_cleaned = spotify_data_cleaned.loc[mask2]
"""
spotify_data_cleaned = spotify_songs
spotify_data_cleaned.track_album_release_date.str[:4]
spotify_data_cleaned.track_album_release_date.str[5:7]
spotify_data_cleaned = spotify_data_cleaned.assign(
    track_album_release_month = spotify_data_cleaned.track_album_release_date.str[5:7],
    track_album_release_year = spotify_data_cleaned.track_album_release_date.str[:4],
)
spotify_data_cleaned.drop(columns="track_album_release_date",inplace=True)
spotify_data_cleaned.track_album_release_year = spotify_data_cleaned.track_album_release_year.astype("int64")
"""
mask = (spotify_data_cleaned.track_popularity > 0)
spotify_data_cleaned = spotify_data_cleaned.loc[mask]
"""
# Out:
# '\nmask = (spotify_data_cleaned.track_popularity > 0)\nspotify_data_cleaned = spotify_data_cleaned.loc[mask]\n'

# %%
from sklearn.preprocessing import MinMaxScaler

def normalisation(data):
    columns = ["track_popularity_var","danceability_var","energy_var","loudness_var","speechiness_var","acousticness_var","instrumentalness_var","liveness_var","valence_var","tempo_var", "duration_ms_var", "track_album_release_year_var","track_popularity_mean","danceability_mean","energy_mean","loudness_mean","speechiness_mean","acousticness_mean","instrumentalness_mean","liveness_mean","valence_mean","tempo_mean", "duration_ms_mean", "track_album_release_year_mean"]
    data_norme = data[columns]
    scaler = MinMaxScaler(feature_range=(0,1))
    data_norme = pd.DataFrame(scaler.fit_transform(data_norme), columns=columns)
    return data_norme

# %%
playlist_mean = spotify_data_cleaned.groupby(['playlist_name'])["track_popularity","danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo", "duration_ms", "track_album_release_year"].mean()
playlist_var = spotify_data_cleaned.groupby(['playlist_name'])["track_popularity","danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo", "duration_ms", "track_album_release_year"].var()
playlist_mean.columns = ["track_popularity_mean","danceability_mean","energy_mean","loudness_mean","speechiness_mean","acousticness_mean","instrumentalness_mean","liveness_mean","valence_mean","tempo_mean", "duration_ms_mean", "track_album_release_year_mean"]
playlist_var.columns = ["track_popularity_var","danceability_var","energy_var","loudness_var","speechiness_var","acousticness_var","instrumentalness_var","liveness_var","valence_var","tempo_var", "duration_ms_var", "track_album_release_year_var"]

playlist = playlist_mean.join(playlist_var)
playlist.dropna(inplace=True)

playlist_normed = pd.DataFrame(normalisation(playlist))
playlist_normed.index = playlist.index


playlist_normed["playlist_genre"] = ""
playlist_normed.info()

test = pd.DataFrame(playlist)
test
# Out:
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <class 'pandas.core.frame.DataFrame'>
# Index: 448 entries, "Permanent Wave" to 🤩🤪Post Teen Pop🤪🤩
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   track_popularity_var           448 non-null    float64
#  1   danceability_var               448 non-null    float64
#  2   energy_var                     448 non-null    float64
#  3   loudness_var                   448 non-null    float64
#  4   speechiness_var                448 non-null    float64
#  5   acousticness_var               448 non-null    float64
#  6   instrumentalness_var           448 non-null    float64
#  7   liveness_var                   448 non-null    float64
#  8   valence_var                    448 non-null    float64
#  9   tempo_var                      448 non-null    float64
#  10  duration_ms_var                448 non-null    float64
#  11  track_album_release_year_var   448 non-null    float64
#  12  track_popularity_mean          448 non-null    float64
#  13  danceability_mean              448 non-null    float64
#  14  energy_mean                    448 non-null    float64
#  15  loudness_mean                  448 non-null    float64
#  16  speechiness_mean               448 non-null    float64
#  17  acousticness_mean              448 non-null    float64
#  18  instrumentalness_mean          448 non-null    float64
#  19  liveness_mean                  448 non-null    float64
#  20  valence_mean                   448 non-null    float64
#  21  tempo_mean                     448 non-null    float64
#  22  duration_ms_mean               448 non-null    float64
#  23  track_album_release_year_mean  448 non-null    float64
#  24  playlist_genre                 448 non-null    object
# dtypes: float64(24), object(1)
# memory usage: 91.0+ KB
#                                                     track_popularity_mean  \
# playlist_name
# "Permanent Wave"                                                36.913043
# 10er Playlist                                                   69.409836
# 1987-1997 OLD SKOOL JAMZ                                        28.268293
# 2000's hard rock                                                50.111111
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...              67.831325
# ...                                                                   ...
# 💊ELECTRO-HOUSE-TECH💊                                            33.846939
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...              39.752577
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                       32.787879
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...              49.295455
# 🤩🤪Post Teen Pop🤪🤩                                               49.113208
#
#                                                     danceability_mean  \
# playlist_name
# "Permanent Wave"                                             0.661739
# 10er Playlist                                                0.687246
# 1987-1997 OLD SKOOL JAMZ                                     0.706220
# 2000's hard rock                                             0.437867
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...           0.678096
# ...                                                               ...
# 💊ELECTRO-HOUSE-TECH💊                                         0.773459
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...           0.745505
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                    0.753364
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...           0.769898
# 🤩🤪Post Teen Pop🤪🤩                                            0.640981
#
#                                                     energy_mean  \
# playlist_name
# "Permanent Wave"                                       0.717652
# 10er Playlist                                          0.701852
# 1987-1997 OLD SKOOL JAMZ                               0.702000
# 2000's hard rock                                       0.899000
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...     0.687265
# ...                                                         ...
# 💊ELECTRO-HOUSE-TECH💊                                   0.781939
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...     0.741299
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School              0.620212
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...     0.663750
# 🤩🤪Post Teen Pop🤪🤩                                      0.777660
#
#                                                     loudness_mean  \
# playlist_name
# "Permanent Wave"                                       -10.113000
# 10er Playlist                                           -5.584574
# 1987-1997 OLD SKOOL JAMZ                                -7.841927
# 2000's hard rock                                        -4.669733
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      -5.529735
# ...                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                    -7.243786
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      -6.433072
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               -6.727707
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      -6.054352
# 🤩🤪Post Teen Pop🤪🤩                                       -4.746245
#
#                                                     speechiness_mean  \
# playlist_name
# "Permanent Wave"                                            0.041752
# 10er Playlist                                               0.090395
# 1987-1997 OLD SKOOL JAMZ                                    0.057349
# 2000's hard rock                                            0.089822
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.087506
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.085595
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.114460
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.225221
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.182865
# 🤩🤪Post Teen Pop🤪🤩                                           0.059379
#
#                                                     acousticness_mean  \
# playlist_name
# "Permanent Wave"                                             0.083219
# 10er Playlist                                                0.148498
# 1987-1997 OLD SKOOL JAMZ                                     0.150592
# 2000's hard rock                                             0.003040
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...           0.157075
# ...                                                               ...
# 💊ELECTRO-HOUSE-TECH💊                                         0.027674
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...           0.126910
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                    0.151653
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...           0.162167
# 🤩🤪Post Teen Pop🤪🤩                                            0.065317
#
#                                                     instrumentalness_mean  \
# playlist_name
# "Permanent Wave"                                                 0.111289
# 10er Playlist                                                    0.013975
# 1987-1997 OLD SKOOL JAMZ                                         0.007288
# 2000's hard rock                                                 0.085999
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...               0.000574
# ...                                                                   ...
# 💊ELECTRO-HOUSE-TECH💊                                             0.552659
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...               0.178364
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                        0.000812
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...               0.017128
# 🤩🤪Post Teen Pop🤪🤩                                                0.000223
#
#                                                     liveness_mean  \
# playlist_name
# "Permanent Wave"                                         0.153474
# 10er Playlist                                            0.151510
# 1987-1997 OLD SKOOL JAMZ                                 0.138524
# 2000's hard rock                                         0.197442
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...       0.190606
# ...                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                     0.132785
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...       0.196997
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                0.183241
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...       0.146068
# 🤩🤪Post Teen Pop🤪🤩                                        0.211496
#
#                                                     valence_mean  tempo_mean  \
# playlist_name
# "Permanent Wave"                                        0.756957  116.941739
# 10er Playlist                                           0.524885  118.873754
# 1987-1997 OLD SKOOL JAMZ                                0.680976  115.276244
# 2000's hard rock                                        0.466978  135.526022
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      0.536092  118.667337
# ...                                                          ...         ...
# 💊ELECTRO-HOUSE-TECH💊                                    0.394654  124.121663
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      0.336542  123.968804
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               0.361219  128.675162
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      0.630511  123.144284
# 🤩🤪Post Teen Pop🤪🤩                                       0.643283  120.788868
#
#                                                     ...  energy_var  \
# playlist_name                                       ...
# "Permanent Wave"                                    ...    0.036700
# 10er Playlist                                       ...    0.023195
# 1987-1997 OLD SKOOL JAMZ                            ...    0.032649
# 2000's hard rock                                    ...    0.005008
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...  ...    0.022344
# ...                                                 ...         ...
# 💊ELECTRO-HOUSE-TECH💊                                ...    0.023886
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...  ...    0.021056
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School           ...    0.019683
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...  ...    0.012573
# 🤩🤪Post Teen Pop🤪🤩                                   ...    0.018013
#
#                                                     loudness_var  \
# playlist_name
# "Permanent Wave"                                       13.547611
# 10er Playlist                                           2.581009
# 1987-1997 OLD SKOOL JAMZ                                4.492723
# 2000's hard rock                                        1.900822
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      2.924581
# ...                                                          ...
# 💊ELECTRO-HOUSE-TECH💊                                    3.545808
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      5.584970
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               5.687843
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      2.733275
# 🤩🤪Post Teen Pop🤪🤩                                       2.999682
#
#                                                     speechiness_var  \
# playlist_name
# "Permanent Wave"                                           0.000487
# 10er Playlist                                              0.007738
# 1987-1997 OLD SKOOL JAMZ                                   0.001087
# 2000's hard rock                                           0.002892
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...         0.005447
# ...                                                             ...
# 💊ELECTRO-HOUSE-TECH💊                                       0.004190
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...         0.007653
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                  0.017237
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...         0.012679
# 🤩🤪Post Teen Pop🤪🤩                                          0.001213
#
#                                                     acousticness_var  \
# playlist_name
# "Permanent Wave"                                            0.012580
# 10er Playlist                                               0.037096
# 1987-1997 OLD SKOOL JAMZ                                    0.039626
# 2000's hard rock                                            0.000051
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.040184
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.002815
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.029102
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.030774
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.026060
# 🤩🤪Post Teen Pop🤪🤩                                           0.013371
#
#                                                     instrumentalness_var  \
# playlist_name
# "Permanent Wave"                                                0.046167
# 10er Playlist                                                   0.010850
# 1987-1997 OLD SKOOL JAMZ                                        0.000978
# 2000's hard rock                                                0.037269
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...              0.000010
# ...                                                                  ...
# 💊ELECTRO-HOUSE-TECH💊                                            0.137128
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...              0.075486
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                       0.000014
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...              0.004318
# 🤩🤪Post Teen Pop🤪🤩                                               0.000002
#
#                                                     liveness_var  valence_var  \
# playlist_name
# "Permanent Wave"                                        0.008846     0.024119
# 10er Playlist                                           0.008542     0.032461
# 1987-1997 OLD SKOOL JAMZ                                0.011340     0.038048
# 2000's hard rock                                        0.011850     0.027313
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      0.017156     0.039892
# ...                                                          ...          ...
# 💊ELECTRO-HOUSE-TECH💊                                    0.013960     0.070822
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      0.029500     0.038030
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               0.022399     0.039552
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      0.014123     0.029478
# 🤩🤪Post Teen Pop🤪🤩                                       0.027469     0.040836
#
#                                                       tempo_var  \
# playlist_name
# "Permanent Wave"                                     240.713061
# 10er Playlist                                        625.483081
# 1987-1997 OLD SKOOL JAMZ                             601.852215
# 2000's hard rock                                     980.847676
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...   691.326420
# ...                                                         ...
# 💊ELECTRO-HOUSE-TECH💊                                   3.649047
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...    27.929658
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School            599.408038
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...  1246.196456
# 🤩🤪Post Teen Pop🤪🤩                                    550.355168
#
#                                                     duration_ms_var  \
# playlist_name
# "Permanent Wave"                                       3.062440e+09
# 10er Playlist                                          1.092367e+09
# 1987-1997 OLD SKOOL JAMZ                               1.507177e+09
# 2000's hard rock                                       3.113782e+09
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...     8.795524e+08
# ...                                                             ...
# 💊ELECTRO-HOUSE-TECH💊                                   1.010587e+10
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...     2.532542e+09
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School              2.064410e+09
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...     7.758675e+08
# 🤩🤪Post Teen Pop🤪🤩                                      6.335520e+08
#
#                                                     track_album_release_year_var
# playlist_name
# "Permanent Wave"                                                      173.249012
# 10er Playlist                                                           6.123497
# 1987-1997 OLD SKOOL JAMZ                                               70.180488
# 2000's hard rock                                                       13.582828
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...                     12.400823
# ...                                                                          ...
# 💊ELECTRO-HOUSE-TECH💊                                                    3.250999
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...                      2.582045
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                               0.445475
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...                      0.476489
# 🤩🤪Post Teen Pop🤪🤩                                                      33.484761
#
# [448 rows x 24 columns]

# %%
def ajout_genre() :
    c = 0
    for i in playlist_normed.index :
        df = spotify_data_cleaned.loc[spotify_data_cleaned["playlist_name"] == i]
        playlist_normed['playlist_genre'].iloc[c] = df['playlist_genre'].iloc[0]
        c+=1

ajout_genre() 
playlist_normed
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#                                                     track_popularity_var  \
# playlist_name
# "Permanent Wave"                                                0.208138
# 10er Playlist                                                   0.154141
# 1987-1997 OLD SKOOL JAMZ                                        0.381966
# 2000's hard rock                                                0.275303
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...              0.215684
# ...                                                                  ...
# 💊ELECTRO-HOUSE-TECH💊                                            0.259806
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...              0.282563
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                       0.401307
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...              0.124955
# 🤩🤪Post Teen Pop🤪🤩                                               0.415451
#
#                                                     danceability_var  \
# playlist_name
# "Permanent Wave"                                            0.208593
# 10er Playlist                                               0.363193
# 1987-1997 OLD SKOOL JAMZ                                    0.327076
# 2000's hard rock                                            0.258611
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.245949
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.216897
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.259212
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.474969
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.310038
# 🤩🤪Post Teen Pop🤪🤩                                           0.279060
#
#                                                     energy_var  loudness_var  \
# playlist_name
# "Permanent Wave"                                      0.318449      0.124205
# 10er Playlist                                         0.194433      0.016364
# 1987-1997 OLD SKOOL JAMZ                              0.281255      0.035163
# 2000's hard rock                                      0.027430      0.009675
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...    0.186627      0.019742
# ...                                                        ...           ...
# 💊ELECTRO-HOUSE-TECH💊                                  0.200783      0.025851
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...    0.174795      0.045904
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School             0.162188      0.046915
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...    0.096897      0.017861
# 🤩🤪Post Teen Pop🤪🤩                                     0.146854      0.020481
#
#                                                     speechiness_var  \
# playlist_name
# "Permanent Wave"                                           0.015583
# 10er Playlist                                              0.249727
# 1987-1997 OLD SKOOL JAMZ                                   0.034958
# 2000's hard rock                                           0.093242
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...         0.175733
# ...                                                             ...
# 💊ELECTRO-HOUSE-TECH💊                                       0.135139
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...         0.246981
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                  0.556439
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...         0.409273
# 🤩🤪Post Teen Pop🤪🤩                                          0.039011
#
#                                                     acousticness_var  \
# playlist_name
# "Permanent Wave"                                            0.081017
# 10er Playlist                                               0.239544
# 1987-1997 OLD SKOOL JAMZ                                    0.255904
# 2000's hard rock                                            0.000000
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.259509
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.017873
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.187848
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.198662
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.168183
# 🤩🤪Post Teen Pop🤪🤩                                           0.086130
#
#                                                     instrumentalness_var  \
# playlist_name
# "Permanent Wave"                                                0.270351
# 10er Playlist                                                   0.063534
# 1987-1997 OLD SKOOL JAMZ                                        0.005726
# 2000's hard rock                                                0.218248
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...              0.000059
# ...                                                                  ...
# 💊ELECTRO-HOUSE-TECH💊                                            0.803016
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...              0.442042
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                       0.000079
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...              0.025285
# 🤩🤪Post Teen Pop🤪🤩                                               0.000010
#
#                                                     liveness_var  valence_var  \
# playlist_name
# "Permanent Wave"                                        0.078972     0.206560
# 10er Playlist                                           0.076091     0.313324
# 1987-1997 OLD SKOOL JAMZ                                0.102568     0.384842
# 2000's hard rock                                        0.107388     0.247438
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      0.157584     0.408436
# ...                                                          ...          ...
# 💊ELECTRO-HOUSE-TECH💊                                    0.127353     0.804325
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      0.274360     0.384607
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               0.207182     0.404096
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      0.128891     0.275147
# 🤩🤪Post Teen Pop🤪🤩                                       0.255144     0.420520
#
#                                                     tempo_var  ...  \
# playlist_name                                                  ...
# "Permanent Wave"                                     0.128569  ...
# 10er Playlist                                        0.335152  ...
# 1987-1997 OLD SKOOL JAMZ                             0.322465  ...
# 2000's hard rock                                     0.525948  ...
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...   0.370504  ...
# ...                                                       ...  ...
# 💊ELECTRO-HOUSE-TECH💊                                 0.001289  ...
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...   0.014325  ...
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School            0.321152  ...
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...   0.668414  ...
# 🤩🤪Post Teen Pop🤪🤩                                    0.294816  ...
#
#                                                     loudness_mean  \
# playlist_name
# "Permanent Wave"                                         0.693573
# 10er Playlist                                            0.906427
# 1987-1997 OLD SKOOL JAMZ                                 0.800322
# 2000's hard rock                                         0.949428
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...       0.909005
# ...                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                     0.828438
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...       0.866544
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                0.852695
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...       0.884346
# 🤩🤪Post Teen Pop🤪🤩                                        0.945832
#
#                                                     speechiness_mean  \
# playlist_name
# "Permanent Wave"                                            0.049566
# 10er Playlist                                               0.208123
# 1987-1997 OLD SKOOL JAMZ                                    0.100405
# 2000's hard rock                                            0.206255
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.198705
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.192476
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.286564
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.647603
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.509538
# 🤩🤪Post Teen Pop🤪🤩                                           0.107023
#
#                                                     acousticness_mean  \
# playlist_name
# "Permanent Wave"                                             0.109017
# 10er Playlist                                                0.197775
# 1987-1997 OLD SKOOL JAMZ                                     0.200622
# 2000's hard rock                                             0.000000
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...           0.209437
# ...                                                               ...
# 💊ELECTRO-HOUSE-TECH💊                                         0.033494
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...           0.168423
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                    0.202065
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...           0.216361
# 🤩🤪Post Teen Pop🤪🤩                                            0.084676
#
#                                                     instrumentalness_mean  \
# playlist_name
# "Permanent Wave"                                                 0.134061
# 10er Playlist                                                    0.016833
# 1987-1997 OLD SKOOL JAMZ                                         0.008778
# 2000's hard rock                                                 0.103596
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...               0.000690
# ...                                                                   ...
# 💊ELECTRO-HOUSE-TECH💊                                             0.665749
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...               0.214862
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                        0.000977
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...               0.020632
# 🤩🤪Post Teen Pop🤪🤩                                                0.000267
#
#                                                     liveness_mean  \
# playlist_name
# "Permanent Wave"                                         0.056671
# 10er Playlist                                            0.054013
# 1987-1997 OLD SKOOL JAMZ                                 0.036444
# 2000's hard rock                                         0.116160
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...       0.106911
# ...                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                     0.028678
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...       0.115558
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                0.096947
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...       0.046651
# 🤩🤪Post Teen Pop🤪🤩                                        0.135176
#
#                                                     valence_mean  tempo_mean  \
# playlist_name
# "Permanent Wave"                                        0.890933    0.421826
# 10er Playlist                                           0.600701    0.466382
# 1987-1997 OLD SKOOL JAMZ                                0.795910    0.383416
# 2000's hard rock                                        0.528281    0.850418
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      0.614716    0.461621
# ...                                                          ...         ...
# 💊ELECTRO-HOUSE-TECH💊                                    0.437832    0.587410
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      0.365156    0.583884
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               0.396017    0.692423
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      0.732799    0.564869
# 🤩🤪Post Teen Pop🤪🤩                                       0.748771    0.510548
#
#                                                     duration_ms_mean  \
# playlist_name
# "Permanent Wave"                                            0.493963
# 10er Playlist                                               0.366928
# 1987-1997 OLD SKOOL JAMZ                                    0.502109
# 2000's hard rock                                            0.399206
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.309571
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.589294
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.282782
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.338426
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.200527
# 🤩🤪Post Teen Pop🤪🤩                                           0.288384
#
#                                                     track_album_release_year_mean  \
# playlist_name
# "Permanent Wave"                                                         0.396098
# 10er Playlist                                                            0.869493
# 1987-1997 OLD SKOOL JAMZ                                                 0.512770
# 2000's hard rock                                                         0.611022
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...                       0.898398
# ...                                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                                     0.934647
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...                       0.941297
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                                0.929065
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...                       0.976440
# 🤩🤪Post Teen Pop🤪🤩                                                        0.833219
#
#                                                     playlist_genre
# playlist_name
# "Permanent Wave"                                              rock
# 10er Playlist                                                  pop
# 1987-1997 OLD SKOOL JAMZ                                       r&b
# 2000's hard rock                                              rock
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...             edm
# ...                                                            ...
# 💊ELECTRO-HOUSE-TECH💊                                           edm
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...             edm
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                      rap
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...           latin
# 🤩🤪Post Teen Pop🤪🤩                                              pop
#
# [448 rows x 25 columns]

# %%
playlist_normed_quanti = playlist_normed.drop(columns="playlist_genre",axis=1)
print(np.any(np.isnan(playlist_normed_quanti)))
# Out:
# False

# %%
aftd = MDS(n_components=5,dissimilarity="euclidean")
dist = aftd.fit_transform(playlist_normed_quanti)
dist
# Out:
# array([[-0.40859954, -0.63813626, -0.11431708,  0.37243005, -0.05861189],
#        [-0.00114516,  0.1632121 ,  0.36827622,  0.11408018,  0.05874887],
#        [-0.10535839, -0.5156275 ,  0.09147008,  0.19046202, -0.08153983],
#        ...,
#        [ 0.48316539,  0.22380356, -0.21617769, -0.3347215 ,  0.20578367],
#        [ 0.46988429,  0.06974196,  0.2585169 , -0.04723648,  0.35799209],
#        [-0.28909757, -0.13707154,  0.27193306, -0.04389027,  0.25627369]])

# %%
cls = AgglomerativeClustering(linkage="ward", affinity="euclidean",n_clusters=6)
cls.fit(playlist_normed_quanti)
labels = cls.labels_

aftd = MDS(n_components=5,dissimilarity="euclidean")
dist = aftd.fit_transform(playlist_normed_quanti)

sns.scatterplot(
    x=dist[:,0],
    y=dist[:,1],
    hue=playlist_normed.playlist_genre,
    size=labels

)

#add_labels(dist[:,0],dist[:,1],spotify_data_quanti.index)
# Out:
# <AxesSubplot:>

# %%
cls = KMeans(n_clusters=6, init="k-means++")
cls.fit(playlist_normed_quanti)
# Out:
# KMeans(n_clusters=6)

# %%
def scatterplot_pca(
    
    columns=None, hue=None, style=None, data=None, pc1=1, pc2=2, **kwargs
):
    """Diagramme de dispersion dans le premier plan principal.

    Permet d'afficher un diagramme de dispersion lorsque les données
    ont plus de deux dimensions. L'argument `columns` spécifie la
    liste des colonnes à utiliser pour la PCA dans le jeu de données
    `data`. Les arguments `style` et `hue` permettent de spécifier la
    forme et la couleur des marqueurs. Les arguments `pc1` et `pc2`
    permettent de sélectionner les composantes principales (par défaut
    la première et deuxième). Retourne l'objet `Axes` ainsi que le
    modèle `PCA` utilisé pour réduire la dimension.

    :param columns: Les colonnes quantitatives de `data` à utiliser
    :param hue: La colonne de coloration
    :param style: La colonne du style
    :param data: Le dataFrame Pandas
    :param pc1: La composante en abscisse
    :param pc2: La composante en ordonnée

    """
     # Select relevant columns (should be numeric)
    data_quant = data if columns is None else data[columns]
    data_quant = data_quant.drop(
        columns=[e for e in [hue, style] if e is not None], errors="ignore"
    )

    # Reduce to two dimensions if needed
    if data_quant.shape[1] == 2:
        data_pca = data_quant
        pca = None
    else:
        n_components = max(pc1, pc2)
        pca = PCA(n_components=n_components)
        data_pca = pca.fit_transform(data_quant)
        data_pca = pd.DataFrame(
            data_pca[:, [pc1 - 1, pc2 - 1]], columns=[f"PC{pc1}", f"PC{pc2}"]
        )

    # Keep name, force categorical data for hue and steal index to
    # avoid unwanted alignment
    if isinstance(hue, pd.Series):
        if not hue.name:
            hue.name = "hue"
        hue_name = hue.name
    elif isinstance(hue, str):
        hue_name = hue
        hue = data[hue]
    elif isinstance(hue, np.ndarray):
        hue = pd.Series(hue, name="class")
        hue_name = "class"

    hue = hue.astype("category")
    hue.index = data_pca.index
    hue.name = hue_name

    if isinstance(style, pd.Series):
        if not style.name:
            style.name = "style"
        style_name = style.name
    elif isinstance(style, str):
        style_name = style
        style = data[style]
    elif isinstance(style, np.ndarray):
        style = pd.Series(style, name="style")
        style_name = "style"

    full_data = data_pca
    if hue is not None:
        full_data = pd.concat((full_data, hue), axis=1)
        kwargs["hue"] = hue_name
    if style is not None:
        full_data = pd.concat((full_data, style), axis=1)
        kwargs["style"] = style_name

    x, y = data_pca.columns
    ax = sns.scatterplot(x=x, y=y, data=full_data, **kwargs)

    return ax, pca

# %%
scatterplot_pca(data=playlist_normed_quanti,style=cls.labels_,hue=playlist_normed.playlist_genre)
plt.legend(loc = 2, bbox_to_anchor = (1,1))

# %%
adjusted_rand_score(cls.labels_, playlist_normed.playlist_genre)
# Out:
# 0.2264683547724387

# %%
data_kmeans = playlist_normed
data_kmeans["labels_constrained"] = cls.labels_
data_kmeans
# Out:
#                                                     track_popularity_var  \
# playlist_name
# "Permanent Wave"                                                0.208138
# 10er Playlist                                                   0.154141
# 1987-1997 OLD SKOOL JAMZ                                        0.381966
# 2000's hard rock                                                0.275303
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...              0.215684
# ...                                                                  ...
# 💊ELECTRO-HOUSE-TECH💊                                            0.259806
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...              0.282563
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                       0.401307
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...              0.124955
# 🤩🤪Post Teen Pop🤪🤩                                               0.415451
#
#                                                     danceability_var  \
# playlist_name
# "Permanent Wave"                                            0.208593
# 10er Playlist                                               0.363193
# 1987-1997 OLD SKOOL JAMZ                                    0.327076
# 2000's hard rock                                            0.258611
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.245949
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.216897
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.259212
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.474969
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.310038
# 🤩🤪Post Teen Pop🤪🤩                                           0.279060
#
#                                                     energy_var  loudness_var  \
# playlist_name
# "Permanent Wave"                                      0.318449      0.124205
# 10er Playlist                                         0.194433      0.016364
# 1987-1997 OLD SKOOL JAMZ                              0.281255      0.035163
# 2000's hard rock                                      0.027430      0.009675
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...    0.186627      0.019742
# ...                                                        ...           ...
# 💊ELECTRO-HOUSE-TECH💊                                  0.200783      0.025851
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...    0.174795      0.045904
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School             0.162188      0.046915
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...    0.096897      0.017861
# 🤩🤪Post Teen Pop🤪🤩                                     0.146854      0.020481
#
#                                                     speechiness_var  \
# playlist_name
# "Permanent Wave"                                           0.015583
# 10er Playlist                                              0.249727
# 1987-1997 OLD SKOOL JAMZ                                   0.034958
# 2000's hard rock                                           0.093242
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...         0.175733
# ...                                                             ...
# 💊ELECTRO-HOUSE-TECH💊                                       0.135139
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...         0.246981
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                  0.556439
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...         0.409273
# 🤩🤪Post Teen Pop🤪🤩                                          0.039011
#
#                                                     acousticness_var  \
# playlist_name
# "Permanent Wave"                                            0.081017
# 10er Playlist                                               0.239544
# 1987-1997 OLD SKOOL JAMZ                                    0.255904
# 2000's hard rock                                            0.000000
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.259509
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.017873
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.187848
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.198662
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.168183
# 🤩🤪Post Teen Pop🤪🤩                                           0.086130
#
#                                                     instrumentalness_var  \
# playlist_name
# "Permanent Wave"                                                0.270351
# 10er Playlist                                                   0.063534
# 1987-1997 OLD SKOOL JAMZ                                        0.005726
# 2000's hard rock                                                0.218248
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...              0.000059
# ...                                                                  ...
# 💊ELECTRO-HOUSE-TECH💊                                            0.803016
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...              0.442042
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                       0.000079
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...              0.025285
# 🤩🤪Post Teen Pop🤪🤩                                               0.000010
#
#                                                     liveness_var  valence_var  \
# playlist_name
# "Permanent Wave"                                        0.078972     0.206560
# 10er Playlist                                           0.076091     0.313324
# 1987-1997 OLD SKOOL JAMZ                                0.102568     0.384842
# 2000's hard rock                                        0.107388     0.247438
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      0.157584     0.408436
# ...                                                          ...          ...
# 💊ELECTRO-HOUSE-TECH💊                                    0.127353     0.804325
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      0.274360     0.384607
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               0.207182     0.404096
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      0.128891     0.275147
# 🤩🤪Post Teen Pop🤪🤩                                       0.255144     0.420520
#
#                                                     tempo_var  ...  \
# playlist_name                                                  ...
# "Permanent Wave"                                     0.128569  ...
# 10er Playlist                                        0.335152  ...
# 1987-1997 OLD SKOOL JAMZ                             0.322465  ...
# 2000's hard rock                                     0.525948  ...
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...   0.370504  ...
# ...                                                       ...  ...
# 💊ELECTRO-HOUSE-TECH💊                                 0.001289  ...
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...   0.014325  ...
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School            0.321152  ...
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...   0.668414  ...
# 🤩🤪Post Teen Pop🤪🤩                                    0.294816  ...
#
#                                                     speechiness_mean  \
# playlist_name
# "Permanent Wave"                                            0.049566
# 10er Playlist                                               0.208123
# 1987-1997 OLD SKOOL JAMZ                                    0.100405
# 2000's hard rock                                            0.206255
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.198705
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.192476
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.286564
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.647603
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.509538
# 🤩🤪Post Teen Pop🤪🤩                                           0.107023
#
#                                                     acousticness_mean  \
# playlist_name
# "Permanent Wave"                                             0.109017
# 10er Playlist                                                0.197775
# 1987-1997 OLD SKOOL JAMZ                                     0.200622
# 2000's hard rock                                             0.000000
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...           0.209437
# ...                                                               ...
# 💊ELECTRO-HOUSE-TECH💊                                         0.033494
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...           0.168423
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                    0.202065
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...           0.216361
# 🤩🤪Post Teen Pop🤪🤩                                            0.084676
#
#                                                     instrumentalness_mean  \
# playlist_name
# "Permanent Wave"                                                 0.134061
# 10er Playlist                                                    0.016833
# 1987-1997 OLD SKOOL JAMZ                                         0.008778
# 2000's hard rock                                                 0.103596
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...               0.000690
# ...                                                                   ...
# 💊ELECTRO-HOUSE-TECH💊                                             0.665749
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...               0.214862
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                        0.000977
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...               0.020632
# 🤩🤪Post Teen Pop🤪🤩                                                0.000267
#
#                                                     liveness_mean  \
# playlist_name
# "Permanent Wave"                                         0.056671
# 10er Playlist                                            0.054013
# 1987-1997 OLD SKOOL JAMZ                                 0.036444
# 2000's hard rock                                         0.116160
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...       0.106911
# ...                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                     0.028678
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...       0.115558
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                0.096947
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...       0.046651
# 🤩🤪Post Teen Pop🤪🤩                                        0.135176
#
#                                                     valence_mean  tempo_mean  \
# playlist_name
# "Permanent Wave"                                        0.890933    0.421826
# 10er Playlist                                           0.600701    0.466382
# 1987-1997 OLD SKOOL JAMZ                                0.795910    0.383416
# 2000's hard rock                                        0.528281    0.850418
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...      0.614716    0.461621
# ...                                                          ...         ...
# 💊ELECTRO-HOUSE-TECH💊                                    0.437832    0.587410
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...      0.365156    0.583884
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School               0.396017    0.692423
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...      0.732799    0.564869
# 🤩🤪Post Teen Pop🤪🤩                                       0.748771    0.510548
#
#                                                     duration_ms_mean  \
# playlist_name
# "Permanent Wave"                                            0.493963
# 10er Playlist                                               0.366928
# 1987-1997 OLD SKOOL JAMZ                                    0.502109
# 2000's hard rock                                            0.399206
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...          0.309571
# ...                                                              ...
# 💊ELECTRO-HOUSE-TECH💊                                        0.589294
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...          0.282782
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                   0.338426
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...          0.200527
# 🤩🤪Post Teen Pop🤪🤩                                           0.288384
#
#                                                     track_album_release_year_mean  \
# playlist_name
# "Permanent Wave"                                                         0.396098
# 10er Playlist                                                            0.869493
# 1987-1997 OLD SKOOL JAMZ                                                 0.512770
# 2000's hard rock                                                         0.611022
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...                       0.898398
# ...                                                                           ...
# 💊ELECTRO-HOUSE-TECH💊                                                     0.934647
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...                       0.941297
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                                0.929065
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...                       0.976440
# 🤩🤪Post Teen Pop🤪🤩                                                        0.833219
#
#                                                     playlist_genre  \
# playlist_name
# "Permanent Wave"                                              rock
# 10er Playlist                                                  pop
# 1987-1997 OLD SKOOL JAMZ                                       r&b
# 2000's hard rock                                              rock
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...             edm
# ...                                                            ...
# 💊ELECTRO-HOUSE-TECH💊                                           edm
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...             edm
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                      rap
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...           latin
# 🤩🤪Post Teen Pop🤪🤩                                              pop
#
#                                                     labels_constrained
# playlist_name
# "Permanent Wave"                                                     2
# 10er Playlist                                                        5
# 1987-1997 OLD SKOOL JAMZ                                             1
# 2000's hard rock                                                     1
# 2010 - 2011 - 2012 - 2013 - 2014 - 2015 - 2016 ...                   5
# ...                                                                ...
# 💊ELECTRO-HOUSE-TECH💊                                                 3
# 🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018/...                   3
# 🔥💵 Hip Hop, Rap, Heavy 808's - New School                            0
# 🔥🦁 GOOD VIBES ONLY 🦁🔥 // BROEDERLIEFDE || FRENN...                   5
# 🤩🤪Post Teen Pop🤪🤩                                                    1
#
# [448 rows x 26 columns]

# %%
genres = ["rap","rock","r&b","latin","edm","pop"]
for genre in genres:
    print("----------------")
    mask_label = data_kmeans.playlist_genre == genre
    data_masked = data_kmeans.loc[mask_label]
    print(genre, "(",data_masked.shape[0],")")
    
    for i in range(6):
        mask_genre = data_masked.labels_constrained == i
        print("Labels ",i, " : ",data_masked.loc[mask_genre].shape[0]/data_kmeans.loc[mask_label].shape[0] * 100 , "%")
# Out:
# ----------------
# rap ( 77 )
# Labels  0  :  48.05194805194805 %
# Labels  1  :  1.2987012987012987 %
# Labels  2  :  2.5974025974025974 %
# Labels  3  :  5.194805194805195 %
# Labels  4  :  6.493506493506493 %
# Labels  5  :  36.36363636363637 %
# ----------------
# rock ( 72 )
# Labels  0  :  0.0 %
# Labels  1  :  19.444444444444446 %
# Labels  2  :  75.0 %
# Labels  3  :  0.0 %
# Labels  4  :  5.555555555555555 %
# Labels  5  :  0.0 %
# ----------------
# r&b ( 74 )
# Labels  0  :  16.216216216216218 %
# Labels  1  :  21.62162162162162 %
# Labels  2  :  9.45945945945946 %
# Labels  3  :  1.3513513513513513 %
# Labels  4  :  22.972972972972975 %
# Labels  5  :  28.37837837837838 %
# ----------------
# latin ( 77 )
# Labels  0  :  5.194805194805195 %
# Labels  1  :  32.467532467532465 %
# Labels  2  :  3.896103896103896 %
# Labels  3  :  3.896103896103896 %
# Labels  4  :  9.090909090909092 %
# Labels  5  :  45.45454545454545 %
# ----------------
# edm ( 76 )
# Labels  0  :  1.3157894736842104 %
# Labels  1  :  23.684210526315788 %
# Labels  2  :  0.0 %
# Labels  3  :  67.10526315789474 %
# Labels  4  :  2.631578947368421 %
# Labels  5  :  5.263157894736842 %
# ----------------
# pop ( 72 )
# Labels  0  :  1.3888888888888888 %
# Labels  1  :  44.44444444444444 %
# Labels  2  :  4.166666666666666 %
# Labels  3  :  6.944444444444445 %
# Labels  4  :  15.277777777777779 %
# Labels  5  :  27.77777777777778 %

# %%
genres = ["rap","rock","r&b","latin","edm","pop"]
for i in range(6):
    print("----------------")
    print("Label " , i, "(",data_masked.shape[0],")")
    mask_label = data_kmeans.labels_constrained == i
    data_masked = data_kmeans.loc[mask_label]
    
    for genre in genres:
        mask_genre = data_masked.playlist_genre == genre
        print(genre, " : ",data_masked.loc[mask_genre].shape[0]/data_kmeans.loc[mask_label].shape[0] * 100 , "%")
# Out:
# ----------------
# Label  0 ( 72 )
# rap  :  67.27272727272727 %
# rock  :  0.0 %
# r&b  :  21.818181818181817 %
# latin  :  7.2727272727272725 %
# edm  :  1.8181818181818181 %
# pop  :  1.8181818181818181 %
# ----------------
# Label  1 ( 55 )
# rap  :  0.9433962264150944 %
# rock  :  13.20754716981132 %
# r&b  :  15.09433962264151 %
# latin  :  23.58490566037736 %
# edm  :  16.9811320754717 %
# pop  :  30.18867924528302 %
# ----------------
# Label  2 ( 106 )
# rap  :  2.898550724637681 %
# rock  :  78.26086956521739 %
# r&b  :  10.144927536231885 %
# latin  :  4.3478260869565215 %
# edm  :  0.0 %
# pop  :  4.3478260869565215 %
# ----------------
# Label  3 ( 69 )
# rap  :  6.25 %
# rock  :  0.0 %
# r&b  :  1.5625 %
# latin  :  4.6875 %
# edm  :  79.6875 %
# pop  :  7.8125 %
# ----------------
# Label  4 ( 64 )
# rap  :  10.869565217391305 %
# rock  :  8.695652173913043 %
# r&b  :  36.95652173913043 %
# latin  :  15.217391304347828 %
# edm  :  4.3478260869565215 %
# pop  :  23.91304347826087 %
# ----------------
# Label  5 ( 46 )
# rap  :  25.925925925925924 %
# rock  :  0.0 %
# r&b  :  19.444444444444446 %
# latin  :  32.407407407407405 %
# edm  :  3.7037037037037033 %
# pop  :  18.51851851851852 %

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c2ad4461-7f35-42f5-b2d9-f686e8952f67' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
