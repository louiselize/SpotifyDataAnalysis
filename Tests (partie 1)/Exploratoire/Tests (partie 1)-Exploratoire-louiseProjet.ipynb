# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# https://lodgecove.com/what-is-the-spotify-popularity-index/

# %%
spotify_songs = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-01-21/spotify_songs.csv')

# %%
spotify_songs.shape
spotify_songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
# ...

# %%
sns.boxplot(x=spotify_songs.track_popularity)
# Out:
# <AxesSubplot:xlabel='track_popularity'>

# %%
sns.histplot(x=spotify_songs.track_popularity)
# Out:
# <AxesSubplot:xlabel='track_popularity', ylabel='Count'>

# %%
sns.histplot(x=spotify_songs.duration_ms)
# Out:
# <AxesSubplot:xlabel='duration_ms', ylabel='Count'>

# %%
plt.figure(figsize = ( 5 , 3 )) 
  
sns.boxplot( x = spotify_songs.duration_ms / 60000 ) 
  
plt.xlabel( "Durée (en minutes)" , size = 12 ) 
      
plt.show()

# %%
sns.histplot(x=spotify_songs.danceability)
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Count'>

# %%
sns.histplot(x=spotify_songs.energy)
# Out:
# <AxesSubplot:xlabel='energy', ylabel='Count'>

# %%
sns.histplot(x=spotify_songs.key)
# Out:
# <AxesSubplot:xlabel='key', ylabel='Count'>

# %%
sns.histplot(x=spotify_songs.loudness)
# Out:
# <AxesSubplot:xlabel='loudness', ylabel='Count'>

# %%
#sns.histplot(x=spotify_songs.mode)

# %%
sns.histplot(x=spotify_songs.speechiness)
# Out:
# <AxesSubplot:xlabel='speechiness', ylabel='Count'>

# %%
sns.histplot(x=spotify_songs.acousticness)
# Out:
# <AxesSubplot:xlabel='acousticness', ylabel='Count'>

# %%
plt.hist(spotify_songs.instrumentalness)
# Out:
# (array([28042.,   819.,   457.,   416.,   334.,   334.,   408.,   543.,
#           916.,   564.]),
#  array([0.    , 0.0994, 0.1988, 0.2982, 0.3976, 0.497 , 0.5964, 0.6958,
#         0.7952, 0.8946, 0.994 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(spotify_songs.liveness)
# Out:
# <AxesSubplot:xlabel='liveness', ylabel='Count'>

# %%
sns.histplot(spotify_songs.valence)
# Out:
# <AxesSubplot:xlabel='valence', ylabel='Count'>

# %%
sns.histplot(spotify_songs.tempo)
# Out:
# <AxesSubplot:xlabel='tempo', ylabel='Count'>

# %% [markdown]
# premire rq : bizarre autant de 0 pour popularité?

# %%
mask = (spotify_songs.track_popularity == 0)
spotify_songs.loc[mask,["track_popularity","track_name","track_artist"]]
# Out:
#        track_popularity                                         track_name  \
# 476                   0                                              Siren
# 772                   0                                Lollipop (Candyman)
# 801                   0                                   Around The World
# 883                   0                                          I'm Yours
# 934                   0                                      Talk About It
# ...                 ...                                                ...
# 32800                 0                                           Dynamite
# 32810                 0                        Lights & Thunder - Club Mix
# 32813                 0                            Invincible - Radio Edit
# 32821                 0  Unleash (Life In Color Anthem 2014) - Original...
# 32822                 0  It Won't Stop (feat. Chris Brown) - Julian Cal...
#
#               track_artist
# 476                  SUNMI
# ...

# %%
mask = (spotify_songs.track_artist == "Aqua")
spotify_songs.loc[mask,["track_popularity","track_name","track_artist"]]
# Out:
#      track_popularity                        track_name track_artist
# 752                 5                       Barbie Girl         Aqua
# 772                 0               Lollipop (Candyman)         Aqua
# 801                 0                  Around The World         Aqua
# 810                 2  Roses Are Red - Original Version         Aqua
# 831                43                          My Oh My         Aqua

# %%
mask = (spotify_songs.track_popularity >= 95)
spotify_songs.loc[mask]
# Out:
#                      track_id                 track_name         track_artist  \
# 139    6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 344    2Fxmhks0bxGSBdJ92vM42m                    bad guy        Billie Eilish
# 687    7k4t7uLgtOxPwTpFmtJNTY                       Tusa              KAROL G
# 689    3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 694    41L3O37CECZt3N7ziG2z7l                      Yummy        Justin Bieber
# ...                       ...                        ...                  ...
# 30207  2b8fOow8UzyDFAE27YhOZM                   Memories             Maroon 5
# 30209  21jGcNKet2qwijlDFuPiPb                    Circles          Post Malone
# 30210  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 30215  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 30223  2Fxmhks0bxGSBdJ92vM42m                    bad guy        Billie Eilish
#
# ...

# %%
mask = (spotify_songs.track_popularity == 0)
spotify_songs.loc[mask]
# Out:
#                      track_id  \
# 476    1gsb4CFzUMERAkfzAKwrZu
# 772    4yEXem27DzCg8xytvvO3E9
# 801    7vHkU1H73z5NVbGTIyI1DG
# 883    3decfgk2pFkvCzYUFj6ssf
# 934    5KHbu2Go6NBryS0h0TpTNJ
# ...                       ...
# 32800  5yl2YyDgcpERTZoZHD9Etl
# 32810  0ZAPuWOQiiY0nGbLPlozT8
# 32813  5sYzg83Vy4IW4TfE9jwk8g
# 32821  3fgNmvYq0QU5aFHDUMa4cm
# 32822  00UpV14MDfk4CvrMbFvqji
#
#                                               track_name         track_artist  \
# 476                                                Siren                SUNMI
# 772                                  Lollipop (Candyman)                 Aqua
# 801                                     Around The World                 Aqua
# 883                                            I'm Yours  Influencers Worship
# 934                                        Talk About It              Bancali
# ...                                                  ...                  ...
# ...

# %%
mask = (spotify_songs.track_popularity >= 95)
spotify_songs.loc[mask]
# Out:
#                      track_id                 track_name         track_artist  \
# 139    6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 344    2Fxmhks0bxGSBdJ92vM42m                    bad guy        Billie Eilish
# 687    7k4t7uLgtOxPwTpFmtJNTY                       Tusa              KAROL G
# 689    3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 694    41L3O37CECZt3N7ziG2z7l                      Yummy        Justin Bieber
# ...                       ...                        ...                  ...
# 30207  2b8fOow8UzyDFAE27YhOZM                   Memories             Maroon 5
# 30209  21jGcNKet2qwijlDFuPiPb                    Circles          Post Malone
# 30210  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 30215  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 30223  2Fxmhks0bxGSBdJ92vM42m                    bad guy        Billie Eilish
#
# ...

# %% [markdown]
# => on dirait que les moins populaires sont assez "vieilles" et les plus populaires très recentes.
# On suppose aussi que ca peut venir des playlist : a faire : faire une moyenne des popularite en fonction des playlist

# %%
sns.countplot(spotify_songs.playlist_name)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='playlist_name', ylabel='count'>

# %%
sns.countplot(spotify_songs.playlist_name)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='playlist_name', ylabel='count'>

# %% [markdown]
# caracteristique nominales : (nom chhasons artsite albums playlist)
# caracteristiques musicales qauntitatives : (dancability energy ...) (correlation?)
# regarder si lien entre les quantitatives et les playlist et les albums et les artistes
#
# differencier avec trackpopularity et le temps?

# %% [markdown]
# Bonus : lien lo17 regarder les mots qui reviennent le plus dans le titre des playlist

# %%
mask = (spotify_songs.track_artist == "Billie Eilish")
spotify_songs.loc[mask]
# Out:
#                      track_id                     track_name   track_artist  \
# 43     3yNZ5r3LKfdmjoS3gkhUCT   bad guy (with Justin Bieber)  Billie Eilish
# 344    2Fxmhks0bxGSBdJ92vM42m                        bad guy  Billie Eilish
# 689    3ZCTVFBt2Brf31RLEnCkWJ            everything i wanted  Billie Eilish
# 1316   2Fxmhks0bxGSBdJ92vM42m                        bad guy  Billie Eilish
# 1548   3ZCTVFBt2Brf31RLEnCkWJ            everything i wanted  Billie Eilish
# 3107   4JuZQeSRYJfLCqBgBIxxrR   Ocean Eyes - Blackbear Remix  Billie Eilish
# 5077   1RGasjWLZ4qMN7wbtkLa3u                         my boy  Billie Eilish
# 5104   3WxmlTZ85sCYFnuIXmUAEe                    party favor  Billie Eilish
# 5260   2Fxmhks0bxGSBdJ92vM42m                        bad guy  Billie Eilish
# 5261   3ZCTVFBt2Brf31RLEnCkWJ            everything i wanted  Billie Eilish
# 5262   4SSnFejRGlZikf02HLewEF                  bury a friend  Billie Eilish
# ...

# %%
mask = (spotify_songs.acousticness <= 0.00001)
spotify_songs.loc[mask]
# Out:
#                      track_id                            track_name  \
# 1617   5M9kio8FEFiNKyTDGqksy2                 The Bomb Dot Com V2.0
# 1620   3OkhW6KkSI7CUdBkuKPldQ        In Case of Emergency, Dial 411
# 3219   53Kf1deIW8fcRaulTzQTRO                               Le perv
# 3391   5jCOeqjJRnRo27b9Hb8xHp                   "This Is Seagull…."
# 4724   1r8e3HtZOP65v2uiWd17dF                               Deleter
# 5586   7sTVsEhtLy217gr6739xF4                         Ready to Diet
# 7427   4CdH04HcZHMBLtDULDHFfe                           Black Betty
# 7511   7xz4JjmcUyxjLb4ra2rk8q             Bad Blood - Alternate Mix
# 11363  51w6nRCU68klqNfYaaVP2j                 Hi, How're You Doin'?
# 11805  1Krtfh550kyhfWPcRp6SnD                              Overkill
# 12930  5bmS5SJDhaPfT03jMjiv2F               Short Skirt, Bare Knees
# 13844  2Qypz4SJmX4V8i4GA95ksk                                 Empty
# 13893  3G2OX9eOHcgzqArjECc1Ye                                Dreams
# ...

# %% [markdown]
# Virer les courtes musiques

# %%
mask = (spotify_songs.duration_ms >= 500000)
spotify_songs.loc[mask]
# Out:
#                      track_id  \
# 11632  40DlQgMasTSTNt06AyjLa9
# 11674  1N0tGBaY1qyZ7GLBoggpNi
# 11678  4IcEBPHjmpQIRk1WZKfOdO
# 11681  5PsCkpjTbGl6Z3BHwFHRMJ
# 11768  2f0P7iELCvAlV8j6Z3rGDE
# 11770  6Vjk8MNXpQpi0F4BefdTyq
# 11789  5ZgZhzQGCqVwPydT4CkH0W
# 11824  7iLGljK0LNpGamQQEOuCRC
# 11914  2QgWuCtBpNIpl5trmKCxRf
# 11919  7lPjS6Yd4lRk4BsboDsm1H
# 12106  6C3wj5V8mqLYtYqgJCABZW
# 12379  1fDsrQ23eTAVFElUMaf38X
# 12380  5ZgZhzQGCqVwPydT4CkH0W
# 12391  6Vjk8MNXpQpi0F4BefdTyq
# 12400  7iLGljK0LNpGamQQEOuCRC
# 12580  7mzHEzbsl5iOvBRuXwReZU
# 12585  1W1GpfPujmgp2vQqcpUhtU
# 12803  1yl4Lly0mQBJwDeocjsbxc
# 12867  2f0P7iELCvAlV8j6Z3rGDE
# 12986  7itr4N5bXkAWesPUomCNf7
# 13034  2nVHqZbOGkKWzlcy1aMbE7
# 13080  3QfJhbiVGJucxyUbOFiaLY
# 13282  6bOTe8T116DNpwp2H6Hxgh
# 13392  4yqtwO7MQIIXqoiRBPHAgR
# 13394  4fG5viBmXibOWwN119zORo
# 13476  0Rp4akmfqBTpbDM6EoqtNy
# 13556  2QgWuCtBpNIpl5trmKCxRf
# 14173  4WfGrAJVC3A5xhUTja0gUG
# 15378  7itr4N5bXkAWesPUomCNf7
# 15430  6tvs6KCRXP8zKhMmMw3OO1
# ...

# %%
sns.countplot(spotify_songs.playlist_genre)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='playlist_genre', ylabel='count'>

# %%
sns.countplot(spotify_songs.playlist_subgenre)
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='playlist_subgenre', ylabel='count'>

# %%
mask = (spotify_songs.instrumentalness == 0.1)
spotify_songs.loc[mask]
# Out:
#                      track_id         track_name   track_artist  \
# 9798   5NlUfFPL2z3RWAXy8NcRs8     Gimme The Loot  Big Baby Tape
# 14401  190IqlryWu91WBKeDgZqZz  Only in My Dreams     The Marías
# 15320  0fFotmAiRwLfpogfYs48PQ           Lavender      Marillion
# 32742  6ifIqBnnAthTV7PfhZftJq            Liberty        D-wayne
# 32780  3qC3qmZNDXu62hc8YbhWsy           Dear Boy         Avicii
#
#        track_popularity          track_album_id  \
# 9798                 54  2wfJ0bReVxM4Qpy7nYoLTd
# 14401                63  5XX1xVOP61GDQCGaZMLjhO
# 15320                51  1z0n45uHXopsKTLEsqeFUW
# 32742                17  3jbwg4bMilrrWDxp4wD4hJ
# 32780                 7  02h9kO2oLKnLtycgbElKsw
#
#                                         track_album_name  \
# 9798                                          Dragonborn
# 14401                                 Superclean, Vol. I
# 15320  A Singles Collection 1982-1992: Six Of One, Ha...
# ...

# %%
mask = (spotify_songs.duration_ms <= 100000)
spotify_songs.loc[mask]
# Out:
#                      track_id                          track_name  \
# 1204   6xPVnZ5WcK9sh9FyYIkiW3                             Knowing
# 1516   5Xw4HulgAYsJaB9VXOMVLH           Canción del encantamiento
# 2252   02Qo5DFgoGTiBGo4ZUvjXm                       pete davidson
# 2253   1rNNOKF4kiaNmdkpIKNsvd          raindrops (an angel cried)
# 2959   6hHDO5Pk0Dh8k3U0F7bdXG  Cybertronic Purgatory - EP Version
# ...                       ...                                 ...
# 28148  5NMF5emWxHxUcivFDagVhE                     This Is the End
# 28149  4O58jN51aRkuHYWqoJDs1s                             Genesis
# 28157  02T6CSYiN1BwFVFGebLmkd                            The Time
# 28161  5Yq7Nx5q7kL5i2ScG45x60                  The Reddish Flower
# 28164  31odRcgnwvGaIOiqTERaHQ                       Fuck the Game
#
#         track_artist  track_popularity          track_album_id  \
# 1204    Davina Leone                13  02fAKALDV5slNocSfioQlN
# ...

# %%
Q1 = np.percentile(spotify_songs.duration_ms, 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(spotify_songs.duration_ms, 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
print(IQR)

"""# Above Upper bound
upper = spotify_songs.duration_ms >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
# Below Lower bound
lower = spotify_songs.duration_ms <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))"""
# Out:
# 65766.0
# '# Above Upper bound\nupper = spotify_songs.duration_ms >= (Q3+1.5*IQR)\n \nprint("Upper bound:",upper)\nprint(np.where(upper))\n \n# Below Lower bound\nlower = spotify_songs.duration_ms <= (Q1-1.5*IQR)\nprint("Lower bound:", lower)\nprint(np.where(lower))'

# %%
(Q3+1.5*IQR) / 60000
# Out:
# 5.870566666666667

# %%
(Q1-1.5*IQR) / 60000
# Out:
# 1.4861666666666666

# %%
mask = (spotify_songs.duration_ms < (Q3+1.5*IQR))
mask2 = spotify_songs.duration_ms > (Q1-1.5*IQR)
spotify_data_cleaned = spotify_songs.loc[mask]
spotify_data_cleaned = spotify_data_cleaned.loc[mask2]
spotify_data_cleaned.shape
# Out:
# (31446, 23)

# %%
spotify_data_cleaned.track_album_release_date.str[:4]
spotify_data_cleaned.track_album_release_date.str[5:7]
spotify_data_cleaned.assign(
    release_month = spotify_data_cleaned.track_album_release_date.str[5:7],
    release_year = spotify_data_cleaned.track_album_release_date.str[:4]
)
spotify_data_cleaned.drop(columns="track_album_release_date",inplace=True)

# %%
sns.barplot(x=spotify_data_cleaned.track_album_release_date.str[:4],y=spotify_data_cleaned.track_popularity)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-770845489dde> in <module>
# ----> 1 sns.barplot(x=spotify_data_cleaned.track_album_release_date.str[:4],y=spotify_data_cleaned.track_popularity)
#
# /shared-libs/python3.7/py/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'track_album_release_date'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c2ad4461-7f35-42f5-b2d9-f686e8952f67' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
